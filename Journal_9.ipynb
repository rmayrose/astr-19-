# %% [markdown]
# # Code Journal session 9

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.randn(1000)
plt.hist(x, bins=100)

plt.xlabel("x-values")
plt.ylabel("y-values")
plt.title("Journal 9 Hooray!")

plt.savefig("journal_9_fig")
plt.show()
