# %% [markdown]
# # Code Journal session 10

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.random.default_rng().gamma(shape=2.0, scale=2.0, size=1000)
plt.hist(x, bins=100, edgecolor='black')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('Code Journal 10')

plt.show()
plt.savefig('journ10_fig')
